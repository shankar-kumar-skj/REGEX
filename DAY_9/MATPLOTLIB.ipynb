# %% [markdown]
# # MATPLOTLIB

# %%
import matplotlib.pyplot as plt
x = [1,5,3]; y=[4,5,6]

# %%
plt.xlabel("Unknown number")
plt.ylabel("Unknown random data")
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
plt.plot(x, y)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("GBR")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(x, y, marker='o')
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_title("Title")
fig.savefig("output.png")
